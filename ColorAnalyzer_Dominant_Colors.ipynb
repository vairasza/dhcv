# %% [markdown]
# # **Get the dominant color (or second dominant, third dominant, ... ) for each frame and show it as a barcode**

# %% [markdown]
# ## **ANLEITUNG**
# ### **[1. Voreinstellung]** Unter "Paths" (Zelle 4) beide Pfade anpassen.
# ### **[2. Voreinstellung]** In der letzten Zelle (Generate movie barcode) unter "walkthrough_name" den Namen des Walkthroughs anpassen.
# ### **[Dominante Farbe aus jedem Frame bekommen]** Die Zelle bei "Get frame list" ausführen. Der aktuelle Stand wird fortlaufend angezeigt.
# ### **[Bei Abbruch, Verbindungsproblemen, usw.]** Die Zelle bei "Continue process [...]" ausführen. Der aktuelle Stand wird fortlaufend angezeigt.
# ### **[Wenn Prozess abgeschlossen]** Die Zelle bei "Generate the movie barcode" ausführen. Der MovieBarcode wird in verschiedenen Formaten generiert und abgespeichert.
#
# ### **[Alternative]** Es kann auch die zweit- (dritt-, ...) dominanteste Farbe gewonnen werden. Siehe Kommentar in "Get frame list".

# %% [markdown]
# ## Packages needed to be installed

# %%
# !pip install colorthief
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colorthief
#   Downloading colorthief-0.2.1-py2.py3-none-any.whl (6.1 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from colorthief) (7.1.2)
# Installing collected packages: colorthief
# Successfully installed colorthief-0.2.1

# %% [markdown]
# ## Imports

# %%
from colorthief import ColorThief
from natsort import natsorted, ns
# use next line if you want to clear output (right now not needed)
# from IPython.display import clear_output 

import matplotlib.pyplot as plt
import os
import skimage.io as io
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Connection to Google Drive**
# ### Doesn't have to be executed. Alternatively, the mounting can also be initialized manually in the left area.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Paths**
# ### Enter the path for the frames folder and the folder where the results should be saved.

# %%
# folder in which the frames of the walkthrough are saved (Don't forget the "/" at the end)
path_to_game_frames = "/content/drive/MyDrive/digital_humanities/Walkthroughts/Test_Frames/"
# folder in which the results are to be saved (Don't forget the "/" at the end)
path_to_result_data = "/content/drive/MyDrive/digital_humanities/Ergebnisse/Color_Analysis/"

# %% [markdown]
# ## **Get frame list**
# ### for each frame the dominant color is generated and saved in an array
# ### save the names of the frames that have already been analyzed (in case the process is aborted)
# ### show the current status of the process

# %%
# get dominant color for each frame and save it into the dominant_color_arr array

# list of frames in the folder
frames_list = os.listdir(path_to_game_frames)
# sorted list of frames in the folder
frames_list = natsorted(frames_list, alg=ns.PATH | ns.IGNORECASE)

# names of already analyzed frames are saved here. Serves to find out at which point the process should continue to run in the event of a process crash.
backup_check = []

dominant_color_arr = []

for frame in frames_list:
  if frame.split(".")[-1].lower() in {"jpeg", "jpg"}:
    ct_frame = ColorThief(path_to_game_frames + frame)
    # change quality to "2" to get the second most dominat color
    dominant_color_of_ct_frame = ct_frame.get_color(quality=1)
    dominant_color_arr.append(dominant_color_of_ct_frame)

    backup_check.append(frame)

    # Shows how many frames have already been analyzed

    # use next line if you want to clear output (right now not needed)
    #clear_output()
    print(f'\rProcessing: {str(len(dominant_color_arr))} of {str(len(frames_list))} Frames have been analyzed.', end='')
# Out:
# Processing: 5 of 95 Frames have been analyzed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-72b3943ad029> in <module>
#      15     ct_frame = ColorThief(path_to_game_frames + frame)
#      16     # change quality to "2" to get the second most dominat color
# ---> 17     dominant_color_of_ct_frame = ct_frame.get_color(quality=1)
#      18     dominant_color_arr.append(dominant_color_of_ct_frame)
#      19
#
# /usr/local/lib/python3.8/dist-packages/colorthief.py in get_color(self, quality)
#      48         :return tuple: (r, g, b)
#      49         """
# ---> 50         palette = self.get_palette(5, quality)
#      51         return palette[0]
#      52
#
# /usr/local/lib/python3.8/dist-packages/colorthief.py in get_palette(self, color_count, quality)
#      75         # Send array to quantize function which clusters values
#      76         # using median cut algorithm
# ---> 77         cmap = MMCQ.quantize(valid_pixels, color_count)
#      78         return cmap.palette
#      79
#
# /usr/local/lib/python3.8/dist-packages/colorthief.py in quantize(pixels, max_color)
#     218             raise Exception('Wrong number of max colors when quantize.')
#     219
# --> 220         histo = MMCQ.get_histo(pixels)
#     221
#     222         # check that we aren't below maxcolors already
#
# /usr/local/lib/python3.8/dist-packages/colorthief.py in get_histo(pixels)
#     101         for pixel in pixels:
#     102             rval = pixel[0] >> MMCQ.RSHIFT
# --> 103             gval = pixel[1] >> MMCQ.RSHIFT
#     104             bval = pixel[2] >> MMCQ.RSHIFT
#     105             index = MMCQ.get_color_index(rval, gval, bval)
#
# KeyboardInterrupt:

# %% [markdown]
# ## **Continue process after disconnects, time ups, ...**

# %%
# get dominant color for each frame and save it into the dominant_color_arr array

for frame in frames_list:
  if frame.split(".")[-1].lower() in {"jpeg", "jpg"}:
    if frame not in backup_check:
      ct_frame = ColorThief(path_to_game_frames + frame)
      print(path_to_game_frames + frame)
      dominant_color_of_ct_frame = ct_frame.get_color(quality=1)
      dominant_color_arr.append(dominant_color_of_ct_frame)

      backup_check.append(frame)

      # Shows how many frames have already been analyzed

      # use next line if you want to clear output (right now not needed)
      # clear_output()
      print(f'\rProcessing: {str(len(dominant_color_arr))} of {str(len(frames_list))} Frames have been analyzed.', end='')
      
    else: print(f'\rProcessing: searching for already analyzed frames', end='')

# %% [markdown]
# ## **Generate the movie barcode**
# ### and saves as vector graphics (.eps, .svg) and .png and .jpg

# %%
# generates the movie barcode

plt.imshow([[dominant_color_arr[i] for i in range(len(dominant_color_arr))]], extent=[0,len(dominant_color_arr),0,1], aspect='auto')

# adjust here the name of the walkthrough
walkthrough_name = "test"

plt.savefig(path_to_result_data + walkthrough_name + '_dominant_color_for_each_frame.eps', format='eps')
plt.savefig(path_to_result_data + walkthrough_name + '_dominant_color_for_each_frame.svg', format='svg')
plt.savefig(path_to_result_data + walkthrough_name + '_dominant_color_for_each_frame.png')
plt.savefig(path_to_result_data + walkthrough_name + '_dominant_color_for_each_frame.jpg')
