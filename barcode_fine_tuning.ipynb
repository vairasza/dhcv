# %%
from pandas import *
import numpy as np
import matplotlib.pyplot as plt

# %%
# row data for avg color
avg_color_data_settler_3 = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Die_Siedler3\\Die_Siedler3_average_color_row_data.csv")
avg_color_data_diablo_2 = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Diablo2\\Diablo2_average_color_row_data.csv")
avg_color_data_elden_ring = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Elden_Ring\\Elden_Ring_average_color_row_data.csv")
avg_color_data_half_life_2 = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Half_Life2\\Half_Life2_average_color_row_data.csv")
avg_color_data_little_nightmares = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Little_Nightmares\\Little_Nightmares_average_color_row_data.csv")
avg_color_data_nfsmw = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\NFSWM\\NFSMW_average_color_row_data.csv")
avg_color_data_starcraft_2 = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Starcraft2\\Starcraft2_average_color_row_data.csv")
avg_color_data_super_mario_world = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Super_Mario_World\\Super_Mario_World_average_color_row_data.csv")

# output folder for avg color barcodes figure
output_path = "G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Polished_Barcodes\\"

# %%
color_values = data['RGB']
color_values_arr = []
#res = tuple(int(num) for num in test_str.replace('(', '').replace(')', '').replace('...', '').split(', '))
#color_values = (int(x) for x in color_values)
#color_values = map(int, tup) for tup in color_values
for i in color_values:
    color_value = tuple(float(num) for num in i.replace('(', '').replace(')', '').replace('...', '').split(', '))
    color_values_arr.append(color_value)

print(color_values_arr)
print(color_values_arr[0])
print(color_values_arr[10])
# Out:
# [(49.21021809895835, 110.13106445312488, 227.65774088541647), (64.345771484375, 78.39400390624992, 53.376051432291675), (37.81977213541667, 69.47027343750003, 58.690957031250036), (17.915266927083334, 21.178753255208342, 18.590553385416662), (16.985862630208345, 19.974876302083324, 18.053460286458343), (16.971012369791662, 20.014414062499988, 18.102034505208373), (35.870644531250015, 68.66194010416662, 59.8487076822917), (54.95050130208332, 84.86323242187501, 65.01151041666665), (54.67212890625002, 84.94035156250001, 65.28562174479168), (64.23569010416671, 76.89660481770832, 52.47604166666665), (65.05636393229163, 73.84787760416677, 48.873369140624966), (20.318427734374986, 44.05375976562501, 38.39592447916668), (24.18972981770834, 61.0435514322917, 54.19551106770841), (26.228753255208336, 64.34878580729169, 57.206826171875), (24.5073177083333, 63.9615852864584, 56.467418619791616), (14.784469401041628, 13.261790364583357, 11.295924479166628), (22.008948567708323, 53.17508463541667, 
# ...

# %%
def generateColorBars(color_value_arr):

    color_value_arr = tuple(tuple(map(int, tup)) for tup in color_value_arr)
    
    plt.ioff()
    plt.imshow([[color_value_arr[i] for i in range(len(color_value_arr))]], extent=[0,len(color_value_arr),0,3000], aspect='equal')
    plt.ioff()

    # axis adjustments
    plt.xlabel("frame")
    plt.ylabel("average color")
    plt.yticks([])

    #plt.xlim(0, len(color_value_arr))
    #plt.ylim(0, 0.1)

    # enable the line if you want your plot to have a title
    plt.title("AverageColorBarcode for Siedler 3", fontsize= 10, pad=20)

    #plt.savefig(f"{self.outputPathCSV}{self.gameName}_average_color_for_each_frame.eps", format='eps')
    plt.savefig(f"{output_path}_barcodes_alternative_1.svg", format='svg')
    #plt.savefig(f"{self.outputPathCSV}{self.gameName}_average_color_for_each_frame.png")
    #plt.savefig(f"{self.outputPathCSV}{self.gameName}_average_color_for_each_frame.jpg")

    plt.close()

# %%
generateColorBars(color_values_arr)
