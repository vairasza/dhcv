# %%
from pandas import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
# row data for avg color
avg_color_data_settler_3 = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Die_Siedler3\\Die_Siedler3_average_color_row_data.csv")
avg_color_data_diablo_2 = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Diablo2\\Diablo2_average_color_row_data.csv")
avg_color_data_elden_ring = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Elden_Ring\\Elden_Ring_average_color_row_data.csv")
avg_color_data_half_life_2 = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Half_Life2\\Half_Life2_average_color_row_data.csv")
avg_color_data_little_nightmares = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Little_Nightmares\\Little_Nightmares_average_color_row_data.csv")
avg_color_data_nfsmw = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\NFSMW\\NFSMW_average_color_row_data.csv")
avg_color_data_starcraft_2 = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Starcraft2\\Starcraft2_average_color_row_data.csv")
avg_color_data_super_mario_world = read_csv("G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Super_Mario_World\\Super_Mario_World_average_color_row_data.csv")

# output folder for avg color barcodes figure
output_path = "G:\\.shortcut-targets-by-id\\1m8mQSGFIpYWyBBuka4kAy332A9fQSMBX\\digital_humanities\\Ergebnisse\\AverageColor\\Polished_Barcodes\\"

# %%
# get rgb color values from the row data for the game
def getAvgColorValuesArr(row_data_path):
    color_values = row_data_path['RGB']
    color_values_arr = []
 
    for i in color_values:
        color_value = tuple(float(num) for num in i.replace('(', '').replace(')', '').replace('...', '').split(', '))
        color_values_arr.append(color_value)
    
    avg_color_values_arr = tuple(tuple(map(int, tup)) for tup in color_values_arr)
    
    return avg_color_values_arr

# %%
settler_values = getAvgColorValuesArr(avg_color_data_settler_3)
diablo_values = getAvgColorValuesArr(avg_color_data_diablo_2)
elden_ring_values = getAvgColorValuesArr(avg_color_data_elden_ring)
half_life_values = getAvgColorValuesArr(avg_color_data_half_life_2)
little_nightmares_values = getAvgColorValuesArr(avg_color_data_little_nightmares)
nfsmw_values = getAvgColorValuesArr(avg_color_data_nfsmw)
starcraft_values = getAvgColorValuesArr(avg_color_data_starcraft_2)
mario_values = getAvgColorValuesArr(avg_color_data_super_mario_world)

# %%
# alternative 1

def generateColorBarsAltOne():
    figure, position = plt.subplots(8,1)
    figure.set_size_inches(10.5, 25)
    #figure(figsize=(8, 6), dpi=80)

    # Settler 3
    position[0].imshow([[settler_values[i] for i in range(len(settler_values))]], extent=[0,len(settler_values),0,len(settler_values)/4], aspect='equal')
    position[0].set_title("Settler 3", fontsize= 12, pad=10)
    position[0].set_yticks([])
    position[0].set_xticks([])
    #position[0].set_xlabel("frame")

    # Diablo 2
    position[1].imshow([[diablo_values[i] for i in range(len(diablo_values))]], extent=[0,len(diablo_values),0,len(diablo_values)/4], aspect='equal')
    position[1].set_title("Diablo 2", fontsize= 12, pad=10)
    position[1].set_yticks([])
    position[1].set_xticks([])
    #position[1].set_xlabel("frame")

    # Elden Ring
    position[2].imshow([[elden_ring_values[i] for i in range(len(elden_ring_values))]], extent=[0,len(elden_ring_values),0,len(elden_ring_values)/4], aspect='equal')
    position[2].set_title("Elden Ring", fontsize= 12, pad=10)
    position[2].set_yticks([])
    position[2].set_xticks([])
    #position[1].set_xlabel("frame")

    # Half Life 2
    position[3].imshow([[half_life_values[i] for i in range(len(half_life_values))]], extent=[0,len(half_life_values),0,len(half_life_values)/4], aspect='equal')
    position[3].set_title("Half Life 2", fontsize= 12, pad=10)
    position[3].set_yticks([])
    position[3].set_xticks([])
    #position[1].set_xlabel("frame")

    # Little Nighmares
    position[4].imshow([[little_nightmares_values[i] for i in range(len(little_nightmares_values))]], extent=[0,len(little_nightmares_values),0,len(little_nightmares_values)/4], aspect='equal')
    position[4].set_title("Little Nightmares", fontsize= 12, pad=10)
    position[4].set_yticks([])
    position[4].set_xticks([])
    #position[1].set_xlabel("frame")

    # Need for Speed Most Wanted
    position[5].imshow([[nfsmw_values[i] for i in range(len(nfsmw_values))]], extent=[0,len(nfsmw_values),0,len(nfsmw_values)/4], aspect='equal')
    position[5].set_title("Need for Speed Most Wanted", fontsize= 12, pad=10)
    position[5].set_yticks([])
    position[5].set_xticks([])
    #position[1].set_xlabel("frame")

    # Starcraft 2
    position[6].imshow([[starcraft_values[i] for i in range(len(starcraft_values))]], extent=[0,len(starcraft_values),0,len(starcraft_values)/4], aspect='equal')
    position[6].set_title("Starcraft 2", fontsize= 12, pad=10)
    position[6].set_yticks([])
    position[6].set_xticks([])
    #position[1].set_xlabel("frame")

    # Super Mario World
    position[7].imshow([[mario_values[i] for i in range(len(mario_values))]], extent=[0,len(mario_values),0,len(mario_values)/4], aspect='equal')
    position[7].set_title("Need for Speed Most Wanted", fontsize= 12, pad=10)
    position[7].set_yticks([])
    position[7].set_xticks([])
    #position[1].set_xlabel("frame")


    #plt.show()

    plt.savefig(f"{output_path}avg_barcodes_alternative_1.svg", dpi=100, format='svg')

# %%
# alternative 2

def generateColorBarsAltTwo():
    figure, position = plt.subplots(4,2)
    figure.set_size_inches(18, 11)
    #figure(figsize=(8, 6), dpi=80)

    # Settler 3
    position[0, 0].imshow([[settler_values[i] for i in range(len(settler_values))]], extent=[0,len(settler_values),0,len(settler_values)/4], aspect='equal')
    position[0, 0].set_title("Settler 3", fontsize= 12, pad=10)
    position[0, 0].set_yticks([])
    position[0, 0].set_xticks([])
    #position[0].set_xlabel("frame")

    # Diablo 2
    position[0, 1].imshow([[diablo_values[i] for i in range(len(diablo_values))]], extent=[0,len(diablo_values),0,len(diablo_values)/4], aspect='equal')
    position[0, 1].set_title("Diablo 2", fontsize= 12, pad=10)
    position[0, 1].set_yticks([])
    position[0, 1].set_xticks([])
    #position[1].set_xlabel("frame")

    # Elden Ring
    position[1, 0].imshow([[elden_ring_values[i] for i in range(len(elden_ring_values))]], extent=[0,len(elden_ring_values),0,len(elden_ring_values)/4], aspect='equal')
    position[1, 0].set_title("Elden Ring", fontsize= 12, pad=10)
    position[1, 0].set_yticks([])
    position[1, 0].set_xticks([])
    #position[1].set_xlabel("frame")

    # Half Life 2
    position[1, 1].imshow([[half_life_values[i] for i in range(len(half_life_values))]], extent=[0,len(half_life_values),0,len(half_life_values)/4], aspect='equal')
    position[1, 1].set_title("Half Life 2", fontsize= 12, pad=10)
    position[1, 1].set_yticks([])
    position[1, 1].set_xticks([])
    #position[1].set_xlabel("frame")

    # Little Nighmares
    position[2, 0].imshow([[little_nightmares_values[i] for i in range(len(little_nightmares_values))]], extent=[0,len(little_nightmares_values),0,len(little_nightmares_values)/4], aspect='equal')
    position[2, 0].set_title("Little Nightmares", fontsize= 12, pad=10)
    position[2, 0].set_yticks([])
    position[2, 0].set_xticks([])
    #position[1].set_xlabel("frame")

    # Need for Speed Most Wanted
    position[2, 1].imshow([[nfsmw_values[i] for i in range(len(nfsmw_values))]], extent=[0,len(nfsmw_values),0,len(nfsmw_values)/4], aspect='equal')
    position[2, 1].set_title("Need for Speed Most Wanted", fontsize= 12, pad=10)
    position[2, 1].set_yticks([])
    position[2, 1].set_xticks([])
    #position[1].set_xlabel("frame")

    # Starcraft 2
    position[3, 0].imshow([[starcraft_values[i] for i in range(len(starcraft_values))]], extent=[0,len(starcraft_values),0,len(starcraft_values)/4], aspect='equal')
    position[3, 0].set_title("Starcraft 2", fontsize= 12, pad=10)
    position[3, 0].set_yticks([])
    position[3, 0].set_xticks([])
    #position[1].set_xlabel("frame")

    # Super Mario World
    position[3, 1].imshow([[mario_values[i] for i in range(len(mario_values))]], extent=[0,len(mario_values),0,len(mario_values)/4], aspect='equal')
    position[3, 1].set_title("Need for Speed Most Wanted", fontsize= 12, pad=10)
    position[3, 1].set_yticks([])
    position[3, 1].set_xticks([])
    #position[1].set_xlabel("frame")


    #plt.show()

    plt.savefig(f"{output_path}avg_barcodes_alternative_2.svg", dpi=100, format='svg')

# %%
# alternative 3

def generateColorBarsAltThree():
    figure, position = plt.subplots(8,1)
    figure.set_size_inches(10.5, 35)
    #figure(figsize=(8, 6), dpi=80)

    # Settler 3
    position[0].imshow([[settler_values[i] for i in range(len(settler_values))]], extent=[0,len(settler_values),0,len(settler_values)/4], aspect='equal')
    position[0].set_title("Settler 3", fontsize= 12, pad=10)
    position[0].set_yticks([])
    #position[0].set_xticks([])
    position[0].set_xlabel("frame")

    # Diablo 2
    position[1].imshow([[diablo_values[i] for i in range(len(diablo_values))]], extent=[0,len(diablo_values),0,len(diablo_values)/4], aspect='equal')
    position[1].set_title("Diablo 2", fontsize= 12, pad=10)
    position[1].set_yticks([])
    #position[1].set_xticks([])
    position[1].set_xlabel("frame")

    # Elden Ring
    position[2].imshow([[elden_ring_values[i] for i in range(len(elden_ring_values))]], extent=[0,len(elden_ring_values),0,len(elden_ring_values)/4], aspect='equal')
    position[2].set_title("Elden Ring", fontsize= 12, pad=10)
    position[2].set_yticks([])
    #position[2].set_xticks([])
    position[2].set_xlabel("frame")

    # Half Life 2
    position[3].imshow([[half_life_values[i] for i in range(len(half_life_values))]], extent=[0,len(half_life_values),0,len(half_life_values)/4], aspect='equal')
    position[3].set_title("Half Life 2", fontsize= 12, pad=10)
    position[3].set_yticks([])
    #position[3].set_xticks([])
    position[3].set_xlabel("frame")

    # Little Nighmares
    position[4].imshow([[little_nightmares_values[i] for i in range(len(little_nightmares_values))]], extent=[0,len(little_nightmares_values),0,len(little_nightmares_values)/4], aspect='equal')
    position[4].set_title("Little Nightmares", fontsize= 12, pad=10)
    position[4].set_yticks([])
    #position[4].set_xticks([])
    position[4].set_xlabel("frame")

    # Need for Speed Most Wanted
    position[5].imshow([[nfsmw_values[i] for i in range(len(nfsmw_values))]], extent=[0,len(nfsmw_values),0,len(nfsmw_values)/4], aspect='equal')
    position[5].set_title("Need for Speed Most Wanted", fontsize= 12, pad=10)
    position[5].set_yticks([])
    #position[5].set_xticks([])
    position[5].set_xlabel("frame")

    # Starcraft 2
    position[6].imshow([[starcraft_values[i] for i in range(len(starcraft_values))]], extent=[0,len(starcraft_values),0,len(starcraft_values)/4], aspect='equal')
    position[6].set_title("Starcraft 2", fontsize= 12, pad=10)
    position[6].set_yticks([])
    #position[6].set_xticks([])
    position[6].set_xlabel("frame")

    # Super Mario World
    position[7].imshow([[mario_values[i] for i in range(len(mario_values))]], extent=[0,len(mario_values),0,len(mario_values)/4], aspect='equal')
    position[7].set_title("Need for Speed Most Wanted", fontsize= 12, pad=10)
    position[7].set_yticks([])
    #position[7].set_xticks([])
    position[7].set_xlabel("frame")


    #plt.show()

    plt.savefig(f"{output_path}avg_barcodes_alternative_3.svg", dpi=100, format='svg')

# %%
# alternative 4

def generateColorBarsAltFour():
    figure, position = plt.subplots(4,2)
    figure.set_size_inches(18, 30)
    #figure(figsize=(8, 6), dpi=80)

    # Settler 3
    position[0, 0].imshow([[settler_values[i] for i in range(len(settler_values))]], extent=[0,len(settler_values),0,1], aspect='auto')
    position[0, 0].set_title("Settler 3", fontsize= 12, pad=10)
    position[0, 0].set_yticks([])
    #position[0, 0].set_xticks([])
    position[0, 0].set_xlabel("frame")
    position[0, 0].set_ylabel("average color")

    # Diablo 2
    position[0, 1].imshow([[diablo_values[i] for i in range(len(diablo_values))]], extent=[0,len(diablo_values),0,1], aspect='auto')
    position[0, 1].set_title("Diablo 2", fontsize= 12, pad=10)
    position[0, 1].set_yticks([])
    #position[0, 1].set_xticks([])
    position[0, 1].set_xlabel("frame")
    position[0, 1].set_ylabel("average color")

    # Elden Ring
    position[1, 0].imshow([[elden_ring_values[i] for i in range(len(elden_ring_values))]], extent=[0,len(elden_ring_values),0,1], aspect='auto')
    position[1, 0].set_title("Elden Ring", fontsize= 12, pad=10)
    position[1, 0].set_yticks([])
    #position[1, 0].set_xticks([])
    position[1, 0].set_xlabel("frame")
    position[1, 0].set_ylabel("average color")

    # Half Life 2
    position[1, 1].imshow([[half_life_values[i] for i in range(len(half_life_values))]], extent=[0,len(half_life_values),0,1], aspect='auto')
    position[1, 1].set_title("Half Life 2", fontsize= 12, pad=10)
    position[1, 1].set_yticks([])
    #position[1, 1].set_xticks([])
    position[1, 1].set_xlabel("frame")
    position[1, 1].set_ylabel("average color")

    # Little Nighmares
    position[2, 0].imshow([[little_nightmares_values[i] for i in range(len(little_nightmares_values))]], extent=[0,len(little_nightmares_values),0,1], aspect='auto')
    position[2, 0].set_title("Little Nightmares", fontsize= 12, pad=10)
    position[2, 0].set_yticks([])
    #position[2, 0].set_xticks([])
    position[2, 0].set_xlabel("frame")
    position[2, 0].set_ylabel("average color")

    # Need for Speed Most Wanted
    position[2, 1].imshow([[nfsmw_values[i] for i in range(len(nfsmw_values))]], extent=[0,len(nfsmw_values),0,1], aspect='auto')
    position[2, 1].set_title("Need for Speed Most Wanted", fontsize= 12, pad=10)
    position[2, 1].set_yticks([])
    #position[2, 1].set_xticks([])
    position[2, 1].set_xlabel("frame")
    position[2, 1].set_ylabel("average color")

    # Starcraft 2
    position[3, 0].imshow([[starcraft_values[i] for i in range(len(starcraft_values))]], extent=[0,len(starcraft_values),0,1], aspect='auto')
    position[3, 0].set_title("Starcraft 2", fontsize= 12, pad=10)
    position[3, 0].set_yticks([])
    #position[3, 0].set_xticks([])
    position[3, 0].set_xlabel("frame")
    position[3, 0].set_ylabel("average color")

    # Super Mario World
    position[3, 1].imshow([[mario_values[i] for i in range(len(mario_values))]], extent=[0,len(mario_values),0,1], aspect='auto')
    position[3, 1].set_title("Need for Speed Most Wanted", fontsize= 12, pad=10)
    position[3, 1].set_yticks([])
    #position[3, 1].set_xticks([])
    position[3, 1].set_xlabel("frame")
    position[3, 1].set_ylabel("average color")


    #plt.show()

    plt.savefig(f"{output_path}avg_barcodes_alternative_4.svg", dpi=100, format='svg')

# %%
generateColorBarsAltFour()

# %%
# notes



color_values = data['RGB']
color_values_arr = []
#res = tuple(int(num) for num in test_str.replace('(', '').replace(')', '').replace('...', '').split(', '))
#color_values = (int(x) for x in color_values)
#color_values = map(int, tup) for tup in color_values
for i in color_values:
    color_value = tuple(float(num) for num in i.replace('(', '').replace(')', '').replace('...', '').split(', '))
    color_values_arr.append(color_value)

print(color_values_arr)
print(color_values_arr[0])
print(color_values_arr[10])

plt.ioff()
plt.imshow([[color_value_arr[i] for i in range(len(color_value_arr))]], extent=[0,len(color_value_arr),0,3000], aspect='equal')
plt.ioff()

# axis adjustments
plt.xlabel("frame")
plt.ylabel("average color")
plt.yticks([])

#plt.xlim(0, len(color_value_arr))
#plt.ylim(0, 0.1)

# enable the line if you want your plot to have a title
plt.title("AverageColorBarcode for Siedler 3", fontsize= 10, pad=20)

#plt.savefig(f"{self.outputPathCSV}{self.gameName}_average_color_for_each_frame.eps", format='eps')
plt.savefig(f"{output_path}_barcodes_alternative_1.svg", format='svg')
#plt.savefig(f"{self.outputPathCSV}{self.gameName}_average_color_for_each_frame.png")
#plt.savefig(f"{self.outputPathCSV}{self.gameName}_average_color_for_each_frame.jpg")

plt.close()
